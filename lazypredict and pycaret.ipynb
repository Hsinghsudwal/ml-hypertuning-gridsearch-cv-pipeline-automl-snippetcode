# %%
#Snippets lazypredict
#import
pip install lazypredict
#data
from sklearn.datasets import load_breast_cancer

data = load_breast_cancer()
X = data.data
y= data.target
#classifier
LazyClassifier(
    verbose=0,
    ignore_warnings=True,
    custom_metric=None,
    predictions=False,
    random_state=42,
    classifiers='all',
)
#Fit data for classification
from lazypredict.Supervised import LazyClassifier
from sklearn.model_selection import train_test_split

# split the data
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=0.3,random_state =0)

# build the lazyclassifier
clf = LazyClassifier(verbose=0,ignore_warnings=True, custom_metric=None)

# fit it
models, predictions = clf.fit(X_train, X_test, y_train, y_test)

# print the best models
print(models)
#Explore model details
model_dictionary = clf.provide_models(X_train,X_test,y_train,y_test)

#best model
model_dictionary['LGBMClassifier']


#Model for regressor
from lazypredict.Supervised import LazyRegressor
from sklearn import datasets
from sklearn.utils import shuffle
import numpy as np

# load the data
boston = datasets.load_boston()
X, y = shuffle(boston.data, boston.target, random_state=0)
X = X.astype(np.float32)

# split the data
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=0.3,random_state =0)

# fit the lazy object
reg = LazyRegressor(verbose=0, ignore_warnings=False, custom_metric=None)
models, predictions = reg.fit(X_train, X_test, y_train, y_test)

# print the results in a table
print(models)

#more detail
model_dictionary = reg.provide_models(X_train,X_test,y_train,y_test)
model_dictionary['ExtraTreesRegressor']

# %%
#Pycrate
pip install pycaret[full]
![image.png](attachment:image.png)
# 1 Import data
# 2 EDA
# 3 Cleaning
# initialize setup
from pycaret.regression import *
s = setup(data, target = 'Price', transform_target = True, log_experiment = True, experiment_name = 'data')

#ML model training and selection
# compare all models
best = compare_models()
# check the final params of best model
best.get_params()
# check the residuals of trained model
plot_model(best, plot = 'residuals_interactive')
plot_model(best, plot = ‘feature’)
evaluate_model(best)

#Deployment and monitoring of ML model
# copy data and remove target variable
data_unseen = data.copy()
data_unseen.drop(‘Price’, axis = 1, inplace = True)
predictions = predict_model(best, data = data_unseen)
#pipeline for next
save_model(best, ‘my_best_pipeline’)
#time forcasting pycrate
#"https://app.datacamp.com/workspace/w/a1c3b451-5404-4143-b8d3-1c1b529bf15b"//

# %%
#classification\regressor
from pycaret.classification import *
from pycaret.regression import *
data = pd.read_csv('/contents/diabetes.csv')
classification = setup(train, target = 'target')
#model tarining and selection
best = compare_models()
#analyze best model
evaluate_model(best)
#predict on new data
predictions = predict_model(best, data= test)
#save best pipeline
save_model(best,'my_pipeline')

# %%
#Shap//"https://github.com/slundberg/shap"
pip install shap
import xgboost
import shap

# train an XGBoost model
X, y = shap.datasets.boston()
model = xgboost.XGBRegressor().fit(X, y)

# explain the model's predictions using SHAP
# (same syntax works for LightGBM, CatBoost, scikit-learn, transformers, Spark, etc.)
explainer = shap.Explainer(model)
shap_values = explainer(X)

# visualize the first prediction's explanation
shap.plots.waterfall(shap_values[0])

# %%
#Automate ml
https://machinelearningmastery.com/automl-libraries-for-python/

# %%
"https://moez-62905.medium.com/top-automl-python-libraries-in-2022-2d306cf7acf0

# %%
Classification: Accuracy, AUC, Recall, Precision, F1, Kappa, MCC
Regression: MAE, MSE, RMSE, R2, RMSLE, MAPE
